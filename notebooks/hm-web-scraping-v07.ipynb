# %% [markdown]
# # Imports

# %%
# %%time
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from datetime import datetime
import re
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
import json
import time

from selenium import webdriver
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

import gc
# Out:
# CPU times: user 1.04 s, sys: 344 ms, total: 1.39 s
# Wall time: 6.79 s

# %%
# functions

def request_soup(url_link):    
    headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X x.y; rv:42.0) Gecko/20100101 Firefox/42.0'}    
    page = requests.get( url, headers = headers)
    soup_obj = BeautifulSoup(page.text, 'html.parser')
    return( soup_obj )

def composition_to_df(list_of_comp):
    """ Creates a dataframe from a list of compositions"""
    keys = []
    values = []

    for idx, element in enumerate(list_of_comp):
        # if idx is even, element is a key (column in dataframe)
        if idx % 2 == 0:
            keys.append(element)
        else:
            values.append(element.strip('%,\n')) #added \n

    # final dataframe
    res = dict(zip(keys,values))
    res = pd.DataFrame(res, index = [0])
    return (res)

# %% [markdown]
# # Data Requesting

# %% [markdown]
# ##  Home Page Scraping

# %%
# all products url
url = 'https://www2.hm.com/en_us/men/products/jeans.html'

# headers for request
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X x.y; rv:42.0) Gecko/20100101 Firefox/42.0'}

# requesting
page = requests.get(url=url, headers=headers)

# instatiating bs4 object
soup = BeautifulSoup(page.text, 'html.parser')

print('Starting Web Scraping')
# Out:
# Starting Web Scraping

# %%
# finding load more products element
p = soup.find('div', class_='load-more-products')

# all products
all_products = int(p.find('h2').get('data-total'))

# products per page
products_per_page = int(p.find('h2').get('data-items-shown'))

# rounding up numer of pages needed for web scraping
total_pages = np.ceil(all_products/products_per_page)

# %% [markdown]
# ##  All products in Home Page Scraping

# %%
# creating a page with all products
url_all_prods = url + '?&offset=0&page-size={}'.format(int(total_pages*products_per_page))

all_prods = requests.get(url = url_all_prods, headers=headers)

# %%
soup = BeautifulSoup(all_prods.text, 'html.parser')#.get('li', class_='product-item')

# soup.find('li', class_ = 'product-item').find('a').get('href') #.get('item-link')  #.get('item-link') #, class_ = 'item-link')
# all find all products listed in homepage
products = soup.find_all('li', class_='product-item')

# get link to all projects
home_links = ['https://www2.hm.com' + link.find('a').get('href') for link in products ]

# %% [markdown]
# ##  All products in Each Product Page

# %%
# %%time

# resulting list of all products to scrap
links = []

for link in home_links:
    # scrap each product in home page list
    single_product = requests.get(link, headers = headers)
    soup = BeautifulSoup(single_product.text, 'html.parser')

    # gets the links to all products listed in a page
    products_ul = soup.find('ul', class_='inputlist clearfix')
    products = products_ul.find_all('a')

    links_ul = []
    links_ul = [ 'https://www2.hm.com' + item.get('href') for item in products]
    links.extend(links_ul)
# Out:
# CPU times: user 22.5 s, sys: 272 ms, total: 22.8 s
# Wall time: 1min 11s

# %%
# getting all unique products listed

# converting to a set and then back to list
links = list(set(links))
links.sort()

# %%
# test bench - in case the website devs change some classes names or anything

# soup.find('h1', class_='primary product-item-headline').text
# soup.find('h1', class_="ProductName-module--container__3e-gi").text
# soup.find('h1', class_="web-component-placeholder breadcrumbs-placeholder").text
class_ = "product-name-price"
class_ = "Heading-module--general__3HQET ProductName-module--productTitle__1T9f0 Heading-module--small__SFfSh"
# soup.find('h1', class_=class_)
soup.find_all(id='js-product-name')

soup.find('hm-product-name', id = 'js-product-name').text
# Out:
# '\n\nSlim Tapered Cropped Jeans\n\n\n\n'

# %%
# links[0]

# %%
# defining base dataframe
df_prods = pd.DataFrame()

for link in links:
    
    # scrap each product in home page list
    single_product = requests.get(link, headers = headers)
    soup = BeautifulSoup(single_product.text, 'html.parser')
    
    # scrap all products listed in a page
    products_ul = soup.find('ul', class_='inputlist clearfix')
    products = products_ul.find_all('a')

    # product headline
    # try:
    #     headline = soup.find('h1', class_='primary product-item-headline').text
    # except:
    #     headline = 'NA'

    headline = soup.find('hm-product-name', id = 'js-product-name').text


    for product in products:
        
        #product it
        sku = product.get('data-articlecode')
       
        # color
        color = product.get('data-color')
        
        # product id
        product_id = sku[:-3]
        
        # style id
        color_id = sku[-3:]

        # link
        link = 'https://www2.hm.com/en_us/productpage.{}.html'.format(sku)

        df_temp = pd.DataFrame( {'sku': sku, 'product_id' :product_id, 'color_id' : color_id, 'color': color, 'headline' : headline, 'link': link}, index = [0] )
        
        df_prods = pd.concat([df_prods, df_temp], axis = 0)


df_prods.drop_duplicates('sku',inplace = True)

df_prods.reset_index(inplace = True, drop = True)

# %%
df_prods.head()
# Out:
#           sku product_id color_id             color  \
# 0  0427159001    0427159      001       Black denim
# 1  0427159002    0427159      002   Blue washed out
# 2  0427159003    0427159      003        Denim blue
# 3  0427159004    0427159      004  Light denim blue
# 4  0427159005    0427159      005   Dark denim blue
#
#                            headline  \
# 0  \n\nTrashed Skinny Jeans\n\n\n\n
# 1  \n\nTrashed Skinny Jeans\n\n\n\n
# 2  \n\nTrashed Skinny Jeans\n\n\n\n
# 3  \n\nTrashed Skinny Jeans\n\n\n\n
# 4  \n\nTrashed Skinny Jeans\n\n\n\n
#
#                                                 link
# 0  https://www2.hm.com/en_us/productpage.04271590...
# 1  https://www2.hm.com/en_us/productpage.04271590...
# 2  https://www2.hm.com/en_us/productpage.04271590...
# 3  https://www2.hm.com/en_us/productpage.04271590...
# 4  https://www2.hm.com/en_us/productpage.04271590...

# %%
gc.collect()
# Out:
# 85329

# %% [markdown]
# ## Individual Scraping

# %% [markdown]
# ### Instantiating a Web Driver

# %%
# starting drive

#options = Options()
#options.headless = True
#driver = webdriver.Firefox(options=options)

# set implicit wait
#driver.implicitly_wait(20) # seconds

# %%
# print(driver.timeouts._implicit_wait/1000)
# print(driver.timeouts._page_load/1000)
# print(driver.timeouts._script/1000)

# %% [markdown]
# ### Scrapping Everything

# %%
# %%time

# attempting to instantiate the driver and close it inside the for loop

df_comp = pd.DataFrame()

# defining driver options
options = Options()
options.headless = True


# wait at max 120s
time_out = 120

for idx, link in enumerate(df_prods['link']):

    # sku
    sku = link.split('.')[3]
    print('scraping page {}/{}: {}'.format( idx+1, len(df_prods), link))
    
    # instantiating the driver
    driver = webdriver.Firefox(options=options)
    # set implicit wait
    driver.implicitly_wait(20) # seconds

    # load web page
    driver.get(link)

    # sleep
    
    time.sleep(3)
    # get price
    # try this class (for no promo days)
    class_price = "ProductPrice-module--productItemPrice__2i2Hc"
    # element = WebDriverWait(driver, timeout=time_out).until( EC.presence_of_element_located( (By.CLASS_NAME, class_price) ) )
    element = WebDriverWait(driver, timeout=time_out).until( EC.visibility_of_element_located( (By.CLASS_NAME, class_price) ) )
    price = element.text

    # if element returns empty, try this other class
    if element.text == '':
        class_price = "price.parbase"
        # element = WebDriverWait(driver, timeout=time_out).until( EC.presence_of_element_located( (By.CLASS_NAME, class_price) ) )
        element = WebDriverWait(driver, timeout=time_out).until( EC.visibility_of_element_located( (By.CLASS_NAME, class_price) ) )
        price = element.text
        
        if price == '':
            price = 'NA'
    
    # get product description   
    class_desc = "ProductDescription-module--descriptionText__1zy9P"      
    # test if description exists
    try: 
        # content = WebDriverWait(driver, timeout=time_out).until(EC.presence_of_element_located( (By.CLASS_NAME, class_desc) ))
        content = WebDriverWait(driver, timeout=time_out).until(EC.visibility_of_element_located( (By.CLASS_NAME, class_desc) ))
        desc = content.text
    except:
        desc = 'NA'
    
    # get text
    class_text = 'ProductAttributesList-module--descriptionListItem__3vUL2'
    # contents = WebDriverWait(driver, timeout=time_out).until( EC.presence_of_all_elements_located( (By.CLASS_NAME, class_text) ) )
    contents = WebDriverWait(driver, timeout=time_out).until( EC.visibility_of_all_elements_located( (By.CLASS_NAME, class_text) ) )

    
    # concatenate all lines of text
    text = str()
    # list with all text
    text = [text + line.text  for line  in contents]

    # separate fit and composition from text
    # if fit or composition is not informed they'll return NA
    fit = 'NA'
    composition = 'NA'
    for element in text:
        if 'fit' in element:
            fit = element
        if 'Composition' in element:
            composition = element    
    
    # saving raw text
    text_raw =' /'.join(text)
    
    # saving results
    df_aux = pd.DataFrame( {'sku' : sku, 'price' : price, 'fit' : fit, 'composition' : composition, 'description' : desc ,'text' : text_raw,}, index = [0] )
    df_comp = pd.concat( [df_comp, df_aux], axis = 0 )     
    
    # closing driver
    #driver.close()
    driver.quit()

    # collecting garbage to reduce memory consumption
    gc.collect()

    # sleep to avoid memory leak
    time.sleep(10)
    # time.sleep(1)

df_comp.reset_index(inplace = True, drop = True)
# Out:
# scraping page 1/174: https://www2.hm.com/en_us/productpage.0427159001.html
# scraping page 2/174: https://www2.hm.com/en_us/productpage.0427159002.html
# scraping page 3/174: https://www2.hm.com/en_us/productpage.0427159003.html
# scraping page 4/174: https://www2.hm.com/en_us/productpage.0427159004.html
# scraping page 5/174: https://www2.hm.com/en_us/productpage.0427159005.html
# scraping page 6/174: https://www2.hm.com/en_us/productpage.0427159006.html
# scraping page 7/174: https://www2.hm.com/en_us/productpage.0427159007.html
# scraping page 8/174: https://www2.hm.com/en_us/productpage.0427159008.html
# scraping page 9/174: https://www2.hm.com/en_us/productpage.0427159010.html
# scraping page 10/174: https://www2.hm.com/en_us/productpage.0427159011.html
# scraping page 11/174: https://www2.hm.com/en_us/productpage.0427159017.html
# scraping page 12/174: https://www2.hm.com/en_us/productpage.0427159022.html
# scraping page 13/174: https://www2.hm.com/en_us/productpage.0427159023.html
# scraping page 14/174: https://www2.hm.com/en_us/productpage.0427159025.html
# scraping page 15/174: https://www2.hm.com/en_us/productpage.0427159027.html
# scraping page 16/174: https://www2.hm.com/en_us/productpage.0690449001.html
# scraping page 17/174: https://www2.hm.com/en_us/productpage.0690449002.html
# scraping page 18/174: https://www2.hm.com/en_us/productpage.0690449006.html
# scraping page 19/174: https://www2.hm.com/en_us/productpage.0690449007.html
# scraping page 20/174: https://www2.hm.com/en_us/productpage.0690449009.html
# scraping page 21/174: https://www2.hm.com/en_us/productpage.0690449011.html
# scraping page 22/174: https://www2.hm.com/en_us/productpage.0690449013.html
# scraping page 23/174: https://www2.hm.com/en_us/productpage.0690449021.html
# scraping page 24/174: https://www2.hm.com/en_us/productpage.0690449022.html
# scraping page 25/174: https://www2.hm.com/en_us/productpage.0690449024.html
# scraping page 26/174: https://www2.hm.com/en_us/productpage.0690449028.html
# scraping page 27/174: https://www2.hm.com/en_us/productpage.0690449035.html
# scraping page 28/174: https://www2.hm.com/en_us/productpage.0690449036.html
# scraping page 29/174: https://www2.hm.com/en_us/productpage.0690449040.html
# scraping page 30/174: https://www2.hm.com/en_us/productpage.0690449043.html
# scraping page 31/174: https://www2.hm.com/en_us/productpage.0690449046.html
# scraping page 32/174: https://www2.hm.com/en_us/productpage.0690449051.html
# scraping page 33/174: https://www2.hm.com/en_us/productpage.0690449056.html
# scraping page 34/174: https://www2.hm.com/en_us/productpage.0751994001.html
# scraping page 35/174: https://www2.hm.com/en_us/productpage.0751994003.html
# scraping page 36/174: https://www2.hm.com/en_us/productpage.0751994004.html
# scraping page 37/174: https://www2.hm.com/en_us/productpage.0751994005.html
# scraping page 38/174: https://www2.hm.com/en_us/productpage.0751994006.html
# scraping page 39/174: https://www2.hm.com/en_us/productpage.0751994007.html
# scraping page 40/174: https://www2.hm.com/en_us/productpage.0751994009.html
# scraping page 41/174: https://www2.hm.com/en_us/productpage.0751994010.html
# scraping page 42/174: https://www2.hm.com/en_us/productpage.0751994014.html
# scraping page 43/174: https://www2.hm.com/en_us/productpage.0751994016.html
# scraping page 44/174: https://www2.hm.com/en_us/productpage.0751994017.html
# scraping page 45/174: https://www2.hm.com/en_us/productpage.0751994018.html
# scraping page 46/174: https://www2.hm.com/en_us/productpage.0751994024.html
# scraping page 47/174: https://www2.hm.com/en_us/productpage.0751994031.html
# scraping page 48/174: https://www2.hm.com/en_us/productpage.0751994034.html
# scraping page 49/174: https://www2.hm.com/en_us/productpage.0811993001.html
# scraping page 50/174: https://www2.hm.com/en_us/productpage.0811993002.html
# scraping page 51/174: https://www2.hm.com/en_us/productpage.0811993003.html
# scraping page 52/174: https://www2.hm.com/en_us/productpage.0811993006.html
# scraping page 53/174: https://www2.hm.com/en_us/productpage.0811993007.html
# scraping page 54/174: https://www2.hm.com/en_us/productpage.0811993021.html
# scraping page 55/174: https://www2.hm.com/en_us/productpage.0811993022.html
# scraping page 56/174: https://www2.hm.com/en_us/productpage.0811993024.html
# scraping page 57/174: https://www2.hm.com/en_us/productpage.0811993025.html
# scraping page 58/174: https://www2.hm.com/en_us/productpage.0811993028.html
# scraping page 59/174: https://www2.hm.com/en_us/productpage.0811993031.html
# scraping page 60/174: https://www2.hm.com/en_us/productpage.0811993034.html
# scraping page 61/174: https://www2.hm.com/en_us/productpage.0811993036.html
# scraping page 62/174: https://www2.hm.com/en_us/productpage.0811993037.html
# scraping page 63/174: https://www2.hm.com/en_us/productpage.0811993039.html
# scraping page 64/174: https://www2.hm.com/en_us/productpage.0811993040.html
# scraping page 65/174: https://www2.hm.com/en_us/productpage.0875105001.html
# scraping page 66/174: https://www2.hm.com/en_us/productpage.0875105002.html
# scraping page 67/174: https://www2.hm.com/en_us/productpage.0875105003.html
# scraping page 68/174: https://www2.hm.com/en_us/productpage.0875105009.html
# scraping page 69/174: https://www2.hm.com/en_us/productpage.0875105011.html
# scraping page 70/174: https://www2.hm.com/en_us/productpage.0875105015.html
# scraping page 71/174: https://www2.hm.com/en_us/productpage.0875105016.html
# scraping page 72/174: https://www2.hm.com/en_us/productpage.0875105017.html
# scraping page 73/174: https://www2.hm.com/en_us/productpage.0875105018.html
# scraping page 74/174: https://www2.hm.com/en_us/productpage.0875105023.html
# scraping page 75/174: https://www2.hm.com/en_us/productpage.0875105024.html
# scraping page 76/174: https://www2.hm.com/en_us/productpage.0875105026.html
# scraping page 77/174: https://www2.hm.com/en_us/productpage.0927964001.html
# scraping page 78/174: https://www2.hm.com/en_us/productpage.0927964002.html
# scraping page 79/174: https://www2.hm.com/en_us/productpage.0927964003.html
# scraping page 80/174: https://www2.hm.com/en_us/productpage.0927964004.html
# scraping page 81/174: https://www2.hm.com/en_us/productpage.0927964005.html
# scraping page 82/174: https://www2.hm.com/en_us/productpage.0927964013.html
# scraping page 83/174: https://www2.hm.com/en_us/productpage.0938875001.html
# scraping page 84/174: https://www2.hm.com/en_us/productpage.0938875002.html
# scraping page 85/174: https://www2.hm.com/en_us/productpage.0938875004.html
# scraping page 86/174: https://www2.hm.com/en_us/productpage.0938875007.html
# scraping page 87/174: https://www2.hm.com/en_us/productpage.0938875008.html
# scraping page 88/174: https://www2.hm.com/en_us/productpage.0938875010.html
# scraping page 89/174: https://www2.hm.com/en_us/productpage.0938875012.html
# scraping page 90/174: https://www2.hm.com/en_us/productpage.0938875013.html
# scraping page 91/174: https://www2.hm.com/en_us/productpage.0938875014.html
# scraping page 92/174: https://www2.hm.com/en_us/productpage.0971061001.html
# scraping page 93/174: https://www2.hm.com/en_us/productpage.0971061002.html
# scraping page 94/174: https://www2.hm.com/en_us/productpage.0971061004.html
# scraping page 95/174: https://www2.hm.com/en_us/productpage.0971061005.html
# scraping page 96/174: https://www2.hm.com/en_us/productpage.0971061006.html
# scraping page 97/174: https://www2.hm.com/en_us/productpage.0974597001.html
# scraping page 98/174: https://www2.hm.com/en_us/productpage.0974597002.html
# scraping page 99/174: https://www2.hm.com/en_us/productpage.0974597003.html
# scraping page 100/174: https://www2.hm.com/en_us/productpage.0974597005.html
# scraping page 101/174: https://www2.hm.com/en_us/productpage.0974597006.html
# scraping page 102/174: https://www2.hm.com/en_us/productpage.0979945001.html
# scraping page 103/174: https://www2.hm.com/en_us/productpage.0979945002.html
# scraping page 104/174: https://www2.hm.com/en_us/productpage.0979945003.html
# scraping page 105/174: https://www2.hm.com/en_us/productpage.0979945009.html
# scraping page 106/174: https://www2.hm.com/en_us/productpage.0985159001.html
# scraping page 107/174: https://www2.hm.com/en_us/productpage.0985159002.html
# scraping page 108/174: https://www2.hm.com/en_us/productpage.0985159003.html
# scraping page 109/174: https://www2.hm.com/en_us/productpage.0985159004.html
# scraping page 110/174: https://www2.hm.com/en_us/productpage.0985159005.html
# scraping page 111/174: https://www2.hm.com/en_us/productpage.0985159006.html
# scraping page 112/174: https://www2.hm.com/en_us/productpage.0985159007.html
# scraping page 113/174: https://www2.hm.com/en_us/productpage.0985159008.html
# scraping page 114/174: https://www2.hm.com/en_us/productpage.0985197001.html
# scraping page 115/174: https://www2.hm.com/en_us/productpage.0985197002.html
# scraping page 116/174: https://www2.hm.com/en_us/productpage.0985197003.html
# scraping page 117/174: https://www2.hm.com/en_us/productpage.0985197004.html
# scraping page 118/174: https://www2.hm.com/en_us/productpage.0985197005.html
# scraping page 119/174: https://www2.hm.com/en_us/productpage.0985197006.html
# scraping page 120/174: https://www2.hm.com/en_us/productpage.0985197007.html
# scraping page 121/174: https://www2.hm.com/en_us/productpage.0993887001.html
# scraping page 122/174: https://www2.hm.com/en_us/productpage.0993887002.html
# scraping page 123/174: https://www2.hm.com/en_us/productpage.0993887004.html
# scraping page 124/174: https://www2.hm.com/en_us/productpage.1004199001.html
# scraping page 125/174: https://www2.hm.com/en_us/productpage.1004199002.html
# scraping page 126/174: https://www2.hm.com/en_us/productpage.1004199003.html
# scraping page 127/174: https://www2.hm.com/en_us/productpage.1004199004.html
# scraping page 128/174: https://www2.hm.com/en_us/productpage.1004199005.html
# scraping page 129/174: https://www2.hm.com/en_us/productpage.1008110001.html
# scraping page 130/174: https://www2.hm.com/en_us/productpage.1008110002.html
# scraping page 131/174: https://www2.hm.com/en_us/productpage.1008110003.html
# scraping page 132/174: https://www2.hm.com/en_us/productpage.1008110005.html
# scraping page 133/174: https://www2.hm.com/en_us/productpage.1008110006.html
# scraping page 134/174: https://www2.hm.com/en_us/productpage.1008549001.html
# scraping page 135/174: https://www2.hm.com/en_us/productpage.1008549002.html
# scraping page 136/174: https://www2.hm.com/en_us/productpage.1008549003.html
# scraping page 137/174: https://www2.hm.com/en_us/productpage.1008549004.html
# scraping page 138/174: https://www2.hm.com/en_us/productpage.1008549006.html
# scraping page 139/174: https://www2.hm.com/en_us/productpage.1008549007.html
# scraping page 140/174: https://www2.hm.com/en_us/productpage.1008549008.html
# scraping page 141/174: https://www2.hm.com/en_us/productpage.1013317001.html
# scraping page 142/174: https://www2.hm.com/en_us/productpage.1013317002.html
# scraping page 143/174: https://www2.hm.com/en_us/productpage.1013317004.html
# scraping page 144/174: https://www2.hm.com/en_us/productpage.1013317005.html
# scraping page 145/174: https://www2.hm.com/en_us/productpage.1013317006.html
# scraping page 146/174: https://www2.hm.com/en_us/productpage.1013317008.html
# scraping page 147/174: https://www2.hm.com/en_us/productpage.1013317010.html
# scraping page 148/174: https://www2.hm.com/en_us/productpage.1013317012.html
# scraping page 149/174: https://www2.hm.com/en_us/productpage.1018704001.html
# scraping page 150/174: https://www2.hm.com/en_us/productpage.1018704002.html
# scraping page 151/174: https://www2.hm.com/en_us/productpage.1018704003.html
# scraping page 152/174: https://www2.hm.com/en_us/productpage.1024256001.html
# scraping page 153/174: https://www2.hm.com/en_us/productpage.1024256002.html
# scraping page 154/174: https://www2.hm.com/en_us/productpage.1024256003.html
# scraping page 155/174: https://www2.hm.com/en_us/productpage.1024256004.html
# scraping page 156/174: https://www2.hm.com/en_us/productpage.1024256005.html
# scraping page 157/174: https://www2.hm.com/en_us/productpage.1024256006.html
# scraping page 158/174: https://www2.hm.com/en_us/productpage.1024256007.html
# scraping page 159/174: https://www2.hm.com/en_us/productpage.1024256008.html
# scraping page 160/174: https://www2.hm.com/en_us/productpage.1024711001.html
# scraping page 161/174: https://www2.hm.com/en_us/productpage.1024711002.html
# scraping page 162/174: https://www2.hm.com/en_us/productpage.1024711004.html
# scraping page 163/174: https://www2.hm.com/en_us/productpage.1024711006.html
# scraping page 164/174: https://www2.hm.com/en_us/productpage.1025726002.html
# scraping page 165/174: https://www2.hm.com/en_us/productpage.1025726003.html
# scraping page 166/174: https://www2.hm.com/en_us/productpage.1027852002.html
# scraping page 167/174: https://www2.hm.com/en_us/productpage.1027852007.html
# scraping page 168/174: https://www2.hm.com/en_us/productpage.1048642001.html
# scraping page 169/174: https://www2.hm.com/en_us/productpage.1048642002.html
# scraping page 170/174: https://www2.hm.com/en_us/productpage.1063426001.html
# scraping page 171/174: https://www2.hm.com/en_us/productpage.1071707001.html
# scraping page 172/174: https://www2.hm.com/en_us/productpage.1071707002.html
# scraping page 173/174: https://www2.hm.com/en_us/productpage.1071707008.html
# scraping page 174/174: https://www2.hm.com/en_us/productpage.1074475001.html
# CPU times: user 49.5 s, sys: 5.4 s, total: 54.9 s
# Wall time: 1h 10min 37s

# %%
# quitting driver

driver.quit()

# %%
gc.collect()
# Out:
# 1694

# %%
df_comp.shape
# Out:
# (174, 6)

# %%
df_comp.head()
# Out:
#           sku   price              fit  \
# 0  0427159001  $39.99  Fit\nSkinny fit
# 1  0427159002  $39.99  Fit\nSkinny fit
# 2  0427159003  $39.99  Fit\nSkinny fit
# 3  0427159004  $39.99  Fit\nSkinny fit
# 4  0427159005  $39.99  Fit\nSkinny fit
#
#                                          composition  \
# 0  Composition\nCotton 91%, Polyester 7%, Spandex 2%
# 1  Composition\nCotton 93%, Polyester 6%, Spandex 1%
# 2  Composition\nCotton 93%, Polyester 6%, Spandex 1%
# 3                Composition\nCotton 99%, Spandex 1%
# 4  Composition\nCotton 72%, Polyester 20%, Modal ...
#
#                                          description  \
# 0  5-pocket jeans in washed stretch denim. Heavil...
# 1  5-pocket jeans in washed stretch denim. Heavil...
# 2  5-pocket jeans in washed stretch denim. Heavil...
# 3  5-pocket jeans in washed stretch denim. Heavil...
# 4  5-pocket jeans in washed stretch denim. Heavil...
#
#                                                 text
# 0  Fit\nSkinny fit /Composition\nCotton 91%, Poly...
# 1  Fit\nSkinny fit /Composition\nCotton 93%, Poly...
# 2  Fit\nSkinny fit /Composition\nCotton 93%, Poly...
# 3  Fit\nSkinny fit /Composition\nCotton 99%, Span...
# 4  Fit\nSkinny fit /Composition\nCotton 72%, Poly...

# %% [markdown]
# # Data Parsing

# %% [markdown]
# ### Composition

# %%
# removing composition using regex

df_comp_aux = df_comp.copy()

comps = []
linings = []

for idx, text in enumerate(df_comp_aux['composition']):
    # case 1 pocket lining present
    if 'Pocket' in text:
        # regex = '(Shell: .*?=Pocket|Cotton.*(?=Pocket))'
        regex = 'Cotton.*(?=Pocket)'
        try:
            comp = re.findall( regex, text, flags=re.DOTALL)[0]
        except:
            comp = 'NA'
    # case 2 pocket lining not present
    else:
        regex = '(Cotton.*(?=Lining)|Cotton.*(?=lining)|Cotton.*%)'
        try:
            comp = re.findall( regex, text, flags=re.DOTALL)[0]
        except:
            comp = 'NA'
        # print(df_comp_aux.loc[idx, 'sku'] + '|' + text +' | ' + comp)
    
    # geting pocket composition:
    regex = '(?<=lining: ).*'
    try:
        lining = re.findall(regex, text, flags=re.DOTALL)[0]
    except:
        lining = 'Not Informed'
    linings.append(lining)
    
    comps.append(comp)
df_comp_aux['comp'] = comps
df_comp_aux['lining'] = linings

# %%
# result
df_comp_aux.head()
# Out:
#           sku   price              fit  \
# 0  0427159001  $39.99  Fit\nSkinny fit
# 1  0427159002  $39.99  Fit\nSkinny fit
# 2  0427159003  $39.99  Fit\nSkinny fit
# 3  0427159004  $39.99  Fit\nSkinny fit
# 4  0427159005  $39.99  Fit\nSkinny fit
#
#                                          composition  \
# 0  Composition\nCotton 91%, Polyester 7%, Spandex 2%
# 1  Composition\nCotton 93%, Polyester 6%, Spandex 1%
# 2  Composition\nCotton 93%, Polyester 6%, Spandex 1%
# 3                Composition\nCotton 99%, Spandex 1%
# 4  Composition\nCotton 72%, Polyester 20%, Modal ...
#
#                                          description  \
# 0  5-pocket jeans in washed stretch denim. Heavil...
# 1  5-pocket jeans in washed stretch denim. Heavil...
# 2  5-pocket jeans in washed stretch denim. Heavil...
# 3  5-pocket jeans in washed stretch denim. Heavil...
# 4  5-pocket jeans in washed stretch denim. Heavil...
#
#                                                 text  \
# 0  Fit\nSkinny fit /Composition\nCotton 91%, Poly...
# 1  Fit\nSkinny fit /Composition\nCotton 93%, Poly...
# 2  Fit\nSkinny fit /Composition\nCotton 93%, Poly...
# 3  Fit\nSkinny fit /Composition\nCotton 99%, Span...
# 4  Fit\nSkinny fit /Composition\nCotton 72%, Poly...
#
#                                               comp        lining
# 0             Cotton 91%, Polyester 7%, Spandex 2%  Not Informed
# 1             Cotton 93%, Polyester 6%, Spandex 1%  Not Informed
# 2             Cotton 93%, Polyester 6%, Spandex 1%  Not Informed
# 3                           Cotton 99%, Spandex 1%  Not Informed
# 4  Cotton 72%, Polyester 20%, Modal 7%, Spandex 1%  Not Informed

# %%
# creating a dataframe for all compositions
df_comp_split = pd.DataFrame()

for composition in df_comp_aux['comp']:
    comp_list = composition.split(' ') 

    # creating a df of compositions
    df_aux = composition_to_df(comp_list)

    # concatenating results
    df_comp_split = pd.concat( [df_comp_split, df_aux], axis = 0 )

df_comp_split.reset_index(inplace = True, drop = True)

# %%
# result
df_comp_aux = pd.concat( [df_comp_aux, df_comp_split], axis = 1 )
df_comp_aux.head()
# Out:
#           sku   price              fit  \
# 0  0427159001  $39.99  Fit\nSkinny fit
# 1  0427159002  $39.99  Fit\nSkinny fit
# 2  0427159003  $39.99  Fit\nSkinny fit
# 3  0427159004  $39.99  Fit\nSkinny fit
# 4  0427159005  $39.99  Fit\nSkinny fit
#
#                                          composition  \
# 0  Composition\nCotton 91%, Polyester 7%, Spandex 2%
# 1  Composition\nCotton 93%, Polyester 6%, Spandex 1%
# 2  Composition\nCotton 93%, Polyester 6%, Spandex 1%
# 3                Composition\nCotton 99%, Spandex 1%
# 4  Composition\nCotton 72%, Polyester 20%, Modal ...
#
#                                          description  \
# 0  5-pocket jeans in washed stretch denim. Heavil...
# 1  5-pocket jeans in washed stretch denim. Heavil...
# 2  5-pocket jeans in washed stretch denim. Heavil...
# 3  5-pocket jeans in washed stretch denim. Heavil...
# 4  5-pocket jeans in washed stretch denim. Heavil...
#
#                                                 text  \
# 0  Fit\nSkinny fit /Composition\nCotton 91%, Poly...
# 1  Fit\nSkinny fit /Composition\nCotton 93%, Poly...
# 2  Fit\nSkinny fit /Composition\nCotton 93%, Poly...
# 3  Fit\nSkinny fit /Composition\nCotton 99%, Span...
# 4  Fit\nSkinny fit /Composition\nCotton 72%, Poly...
#
#                                               comp        lining Cotton  \
# 0             Cotton 91%, Polyester 7%, Spandex 2%  Not Informed     91
# 1             Cotton 93%, Polyester 6%, Spandex 1%  Not Informed     93
# 2             Cotton 93%, Polyester 6%, Spandex 1%  Not Informed     93
# 3                           Cotton 99%, Spandex 1%  Not Informed     99
# 4  Cotton 72%, Polyester 20%, Modal 7%, Spandex 1%  Not Informed     72
#
#   Polyester Spandex Modal Elastomultiester
# 0         7       2   NaN              NaN
# 1         6       1   NaN              NaN
# 2         6       1   NaN              NaN
# 3       NaN       1   NaN              NaN
# 4        20       1     7              NaN

# %%
df_comp_aux.tail()
# Out:
#             sku   price               fit  \
# 169  1063426001  $34.99                NA
# 170  1071707001  $29.99  Fit\nRelaxed fit
# 171  1071707002  $29.99  Fit\nRelaxed fit
# 172  1071707008  $29.99  Fit\nRelaxed fit
# 173  1074475001  $39.99    Fit\nLoose fit
#
#                                            composition  \
# 169                           Composition\nCotton 100%
# 170  Composition\nShell: Cotton 100%\nPocket lining...
# 171  Composition\nShell: Cotton 100%\nPocket lining...
# 172  Composition\nShell: Cotton 100%\nPocket lining...
# 173  Composition\nShell: Cotton 100%\nPocket lining...
#
#                                            description  \
# 169  Edition by is an uncompromising collection of ...
# 170  5-pocket jeans in sturdy cotton denim with a r...
# 171  5-pocket jeans in sturdy cotton denim with a r...
# 172  5-pocket jeans in sturdy cotton denim with a r...
# 173  5-pocket jeans in sturdy cotton denim with har...
#
#                                                   text           comp  \
# 169  Size\nThe model is 188cm/6'2" and wears a size...    Cotton 100%
# 170  Fit\nRelaxed fit /Composition\nShell: Cotton 1...  Cotton 100%\n
# 171  Size\nThe model is 184cm/6'0" and wears a size...  Cotton 100%\n
# 172  Size\nThe model is 182cm/6'0" and wears a size...  Cotton 100%\n
# 173  Size\nThe model is 187cm/6'2" and wears a size...  Cotton 100%\n
#
#                         lining Cotton Polyester Spandex Modal Elastomultiester
# 169               Not Informed    100       NaN     NaN   NaN              NaN
# 170                Cotton 100%    100       NaN     NaN   NaN              NaN
# 171  Polyester 65%, Cotton 35%    100       NaN     NaN   NaN              NaN
# 172  Polyester 65%, Cotton 35%    100       NaN     NaN   NaN              NaN
# 173  Polyester 65%, Cotton 35%    100       NaN     NaN   NaN              NaN

# %% [markdown]
# ### Fit

# %%
# positive lookbehind + words I'm searching + positive lookahead
regex = "((?<=Fit).*(?= fit)|NA)"

df_comp_aux['fit'] = df_comp_aux['fit'].apply(lambda x: re.findall(regex, x, flags=re.DOTALL)[0].strip('\n') ) 
df_comp_aux.head()
# Out:
#           sku   price     fit  \
# 0  0427159001  $39.99  Skinny
# 1  0427159002  $39.99  Skinny
# 2  0427159003  $39.99  Skinny
# 3  0427159004  $39.99  Skinny
# 4  0427159005  $39.99  Skinny
#
#                                          composition  \
# 0  Composition\nCotton 91%, Polyester 7%, Spandex 2%
# 1  Composition\nCotton 93%, Polyester 6%, Spandex 1%
# 2  Composition\nCotton 93%, Polyester 6%, Spandex 1%
# 3                Composition\nCotton 99%, Spandex 1%
# 4  Composition\nCotton 72%, Polyester 20%, Modal ...
#
#                                          description  \
# 0  5-pocket jeans in washed stretch denim. Heavil...
# 1  5-pocket jeans in washed stretch denim. Heavil...
# 2  5-pocket jeans in washed stretch denim. Heavil...
# 3  5-pocket jeans in washed stretch denim. Heavil...
# 4  5-pocket jeans in washed stretch denim. Heavil...
#
#                                                 text  \
# 0  Fit\nSkinny fit /Composition\nCotton 91%, Poly...
# 1  Fit\nSkinny fit /Composition\nCotton 93%, Poly...
# 2  Fit\nSkinny fit /Composition\nCotton 93%, Poly...
# 3  Fit\nSkinny fit /Composition\nCotton 99%, Span...
# 4  Fit\nSkinny fit /Composition\nCotton 72%, Poly...
#
#                                               comp        lining Cotton  \
# 0             Cotton 91%, Polyester 7%, Spandex 2%  Not Informed     91
# 1             Cotton 93%, Polyester 6%, Spandex 1%  Not Informed     93
# 2             Cotton 93%, Polyester 6%, Spandex 1%  Not Informed     93
# 3                           Cotton 99%, Spandex 1%  Not Informed     99
# 4  Cotton 72%, Polyester 20%, Modal 7%, Spandex 1%  Not Informed     72
#
#   Polyester Spandex Modal Elastomultiester
# 0         7       2   NaN              NaN
# 1         6       1   NaN              NaN
# 2         6       1   NaN              NaN
# 3       NaN       1   NaN              NaN
# 4        20       1     7              NaN

# %% [markdown]
# ### Price

# %%
# df_comp_aux = df_comp_aux.copy()

# if there are 2 prices then there is a discount/promo
regex = "\$\d+\.\d+\$\d+.\d+"
df_comp_aux['isPromo'] = df_comp_aux['price'].apply(lambda x: 1 if bool(re.match(regex, x)) else 0)

# first price
regex = "^\$\d+\.\d+"
df_comp_aux['firstPrice'] = df_comp_aux['price'].apply( lambda x: re.findall(regex, x)[0] )

# second price
regex = "\$\d+\.\d+$"
df_comp_aux['secondPrice'] = df_comp_aux['price'].apply( lambda x: re.findall(regex, x)[0] )

# removing
df_comp_aux['firstPrice'] = df_comp_aux['firstPrice'].apply(lambda x: x.strip('$')).astype(float)
df_comp_aux['secondPrice'] = df_comp_aux['secondPrice'].apply(lambda x: x.strip('$')).astype(float)

# 
df_comp_aux['finalPrice'] = df_comp_aux.apply( lambda x: x['firstPrice'] if x['firstPrice'] <= x['secondPrice'] else x['secondPrice'], axis =1 )
df_comp_aux['originalPrice'] = df_comp_aux.apply( lambda x: x['secondPrice'] if x['secondPrice'] >= x['firstPrice'] else x['firstPrice'], axis =1 )

df_comp_aux.drop(['firstPrice', 'secondPrice'], axis = 1, inplace = True)

# %%
# df_comp_aux[df_comp_aux.firstPrice == df_comp_aux.secondPrice]
df_comp_aux.head()
# Out:
#           sku   price     fit  \
# 0  0427159001  $39.99  Skinny
# 1  0427159002  $39.99  Skinny
# 2  0427159003  $39.99  Skinny
# 3  0427159004  $39.99  Skinny
# 4  0427159005  $39.99  Skinny
#
#                                          composition  \
# 0  Composition\nCotton 91%, Polyester 7%, Spandex 2%
# 1  Composition\nCotton 93%, Polyester 6%, Spandex 1%
# 2  Composition\nCotton 93%, Polyester 6%, Spandex 1%
# 3                Composition\nCotton 99%, Spandex 1%
# 4  Composition\nCotton 72%, Polyester 20%, Modal ...
#
#                                          description  \
# 0  5-pocket jeans in washed stretch denim. Heavil...
# 1  5-pocket jeans in washed stretch denim. Heavil...
# 2  5-pocket jeans in washed stretch denim. Heavil...
# 3  5-pocket jeans in washed stretch denim. Heavil...
# 4  5-pocket jeans in washed stretch denim. Heavil...
#
#                                                 text  \
# 0  Fit\nSkinny fit /Composition\nCotton 91%, Poly...
# 1  Fit\nSkinny fit /Composition\nCotton 93%, Poly...
# 2  Fit\nSkinny fit /Composition\nCotton 93%, Poly...
# 3  Fit\nSkinny fit /Composition\nCotton 99%, Span...
# 4  Fit\nSkinny fit /Composition\nCotton 72%, Poly...
#
#                                               comp        lining Cotton  \
# 0             Cotton 91%, Polyester 7%, Spandex 2%  Not Informed     91
# 1             Cotton 93%, Polyester 6%, Spandex 1%  Not Informed     93
# 2             Cotton 93%, Polyester 6%, Spandex 1%  Not Informed     93
# 3                           Cotton 99%, Spandex 1%  Not Informed     99
# 4  Cotton 72%, Polyester 20%, Modal 7%, Spandex 1%  Not Informed     72
#
#   Polyester Spandex Modal Elastomultiester  isPromo  finalPrice  originalPrice
# 0         7       2   NaN              NaN        0       39.99          39.99
# 1         6       1   NaN              NaN        0       39.99          39.99
# 2         6       1   NaN              NaN        0       39.99          39.99
# 3       NaN       1   NaN              NaN        0       39.99          39.99
# 4        20       1     7              NaN        0       39.99          39.99

# %%
print('Found {} promos'.format(df_comp_aux[df_comp_aux['isPromo']== True].shape[0]))
df_comp_aux[df_comp_aux['isPromo'] == True].tail()
# Out:
# Found 0 promos
# Empty DataFrame
# Columns: [sku, price, fit, composition, description, text, comp, lining, Cotton, Polyester, Spandex, Modal, Elastomultiester, isPromo, finalPrice, originalPrice]
# Index: []

# %% [markdown]
# ### Headline

# %%
# removing whitespace characteres

df_prods['headline'] = df_prods['headline'].apply(lambda x: x.strip('\n\t ')) 
df_prods.headline.value_counts()
# Out:
# Slim Jeans                        34
# Skinny Jeans                      26
# Regular Jeans                     23
# Relaxed Jeans                     17
# Trashed Skinny Jeans              15
# Slim Tapered Jeans                14
# Hybrid Regular Tapered Joggers     8
# Regular Tapered Crop Jeans         6
# Skinny Cropped Jeans               5
# Freefit® Slim Jeans                5
# Loose Jeans                        5
# Slim Tapered Cropped Jeans         5
# Hybrid Regular Denim Joggers       3
# Relaxed Pull-on Jeans              3
# Relaxed Denim Joggers              2
# Regular Bootcut Jeans              2
# Cotton Denim Jeans                 1
# Name: headline, dtype: int64

# %%
df_comp_aux.head()
# Out:
#           sku   price     fit  \
# 0  0427159001  $39.99  Skinny
# 1  0427159002  $39.99  Skinny
# 2  0427159003  $39.99  Skinny
# 3  0427159004  $39.99  Skinny
# 4  0427159005  $39.99  Skinny
#
#                                          composition  \
# 0  Composition\nCotton 91%, Polyester 7%, Spandex 2%
# 1  Composition\nCotton 93%, Polyester 6%, Spandex 1%
# 2  Composition\nCotton 93%, Polyester 6%, Spandex 1%
# 3                Composition\nCotton 99%, Spandex 1%
# 4  Composition\nCotton 72%, Polyester 20%, Modal ...
#
#                                          description  \
# 0  5-pocket jeans in washed stretch denim. Heavil...
# 1  5-pocket jeans in washed stretch denim. Heavil...
# 2  5-pocket jeans in washed stretch denim. Heavil...
# 3  5-pocket jeans in washed stretch denim. Heavil...
# 4  5-pocket jeans in washed stretch denim. Heavil...
#
#                                                 text  \
# 0  Fit\nSkinny fit /Composition\nCotton 91%, Poly...
# 1  Fit\nSkinny fit /Composition\nCotton 93%, Poly...
# 2  Fit\nSkinny fit /Composition\nCotton 93%, Poly...
# 3  Fit\nSkinny fit /Composition\nCotton 99%, Span...
# 4  Fit\nSkinny fit /Composition\nCotton 72%, Poly...
#
#                                               comp        lining Cotton  \
# 0             Cotton 91%, Polyester 7%, Spandex 2%  Not Informed     91
# 1             Cotton 93%, Polyester 6%, Spandex 1%  Not Informed     93
# 2             Cotton 93%, Polyester 6%, Spandex 1%  Not Informed     93
# 3                           Cotton 99%, Spandex 1%  Not Informed     99
# 4  Cotton 72%, Polyester 20%, Modal 7%, Spandex 1%  Not Informed     72
#
#   Polyester Spandex Modal Elastomultiester  isPromo  finalPrice  originalPrice
# 0         7       2   NaN              NaN        0       39.99          39.99
# 1         6       1   NaN              NaN        0       39.99          39.99
# 2         6       1   NaN              NaN        0       39.99          39.99
# 3       NaN       1   NaN              NaN        0       39.99          39.99
# 4        20       1     7              NaN        0       39.99          39.99

# %%
df_final = pd.concat( [df_prods, df_comp_aux.drop('sku', axis = 1)], axis =1 )

# adding date time
now = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
df_final['date'] = now
df_final.head()
# Out:
#           sku product_id color_id             color              headline  \
# 0  0427159001    0427159      001       Black denim  Trashed Skinny Jeans
# 1  0427159002    0427159      002   Blue washed out  Trashed Skinny Jeans
# 2  0427159003    0427159      003        Denim blue  Trashed Skinny Jeans
# 3  0427159004    0427159      004  Light denim blue  Trashed Skinny Jeans
# 4  0427159005    0427159      005   Dark denim blue  Trashed Skinny Jeans
#
#                                                 link   price     fit  \
# 0  https://www2.hm.com/en_us/productpage.04271590...  $39.99  Skinny
# 1  https://www2.hm.com/en_us/productpage.04271590...  $39.99  Skinny
# 2  https://www2.hm.com/en_us/productpage.04271590...  $39.99  Skinny
# 3  https://www2.hm.com/en_us/productpage.04271590...  $39.99  Skinny
# 4  https://www2.hm.com/en_us/productpage.04271590...  $39.99  Skinny
#
#                                          composition  \
# 0  Composition\nCotton 91%, Polyester 7%, Spandex 2%
# 1  Composition\nCotton 93%, Polyester 6%, Spandex 1%
# 2  Composition\nCotton 93%, Polyester 6%, Spandex 1%
# 3                Composition\nCotton 99%, Spandex 1%
# 4  Composition\nCotton 72%, Polyester 20%, Modal ...
#
#                                          description  ...        lining  \
# 0  5-pocket jeans in washed stretch denim. Heavil...  ...  Not Informed
# 1  5-pocket jeans in washed stretch denim. Heavil...  ...  Not Informed
# 2  5-pocket jeans in washed stretch denim. Heavil...  ...  Not Informed
# 3  5-pocket jeans in washed stretch denim. Heavil...  ...  Not Informed
# 4  5-pocket jeans in washed stretch denim. Heavil...  ...  Not Informed
#
#   Cotton Polyester Spandex Modal Elastomultiester isPromo finalPrice  \
# 0     91         7       2   NaN              NaN       0      39.99
# 1     93         6       1   NaN              NaN       0      39.99
# 2     93         6       1   NaN              NaN       0      39.99
# 3     99       NaN       1   NaN              NaN       0      39.99
# 4     72        20       1     7              NaN       0      39.99
#
#    originalPrice                 date
# 0          39.99  2022-05-31 20:25:14
# 1          39.99  2022-05-31 20:25:14
# 2          39.99  2022-05-31 20:25:14
# 3          39.99  2022-05-31 20:25:14
# 4          39.99  2022-05-31 20:25:14
#
# [5 rows x 22 columns]

# %%
df_final.columns
# Out:
# Index(['sku', 'product_id', 'color_id', 'color', 'headline', 'link', 'price',
#        'fit', 'composition', 'description', 'text', 'comp', 'lining', 'Cotton',
#        'Polyester', 'Spandex', 'Modal', 'Elastomultiester', 'isPromo',
#        'finalPrice', 'originalPrice', 'date'],
#       dtype='object')

# %%
#sku, product_id, color_id, color, fit, price, headline, 'cotton', 'polyester', 'elastane', 'elasterell_p', 'spandex' 'modal', 'viscose', pocket_lining, text

# renaming some columns
selected_cols = ['finalPrice', 'originalPrice', 'isPromo'] 
rename_cols = ['final_price', 'original_price', 'is_promo'] 

final_cols = dict(zip(selected_cols, rename_cols))
df_final.rename(columns = final_cols, inplace = True )

# converting all columns to lower case
original_col = list(df_final.columns)
lower_col = [col.lower() for col in original_col]
final_cols = dict(zip(original_col, lower_col))

df_final.rename(columns = final_cols, inplace = True )

df_final.head()
# Out:
#           sku product_id color_id             color              headline  \
# 0  0427159001    0427159      001       Black denim  Trashed Skinny Jeans
# 1  0427159002    0427159      002   Blue washed out  Trashed Skinny Jeans
# 2  0427159003    0427159      003        Denim blue  Trashed Skinny Jeans
# 3  0427159004    0427159      004  Light denim blue  Trashed Skinny Jeans
# 4  0427159005    0427159      005   Dark denim blue  Trashed Skinny Jeans
#
#                                                 link   price     fit  \
# 0  https://www2.hm.com/en_us/productpage.04271590...  $39.99  Skinny
# 1  https://www2.hm.com/en_us/productpage.04271590...  $39.99  Skinny
# 2  https://www2.hm.com/en_us/productpage.04271590...  $39.99  Skinny
# 3  https://www2.hm.com/en_us/productpage.04271590...  $39.99  Skinny
# 4  https://www2.hm.com/en_us/productpage.04271590...  $39.99  Skinny
#
#                                          composition  \
# 0  Composition\nCotton 91%, Polyester 7%, Spandex 2%
# 1  Composition\nCotton 93%, Polyester 6%, Spandex 1%
# 2  Composition\nCotton 93%, Polyester 6%, Spandex 1%
# 3                Composition\nCotton 99%, Spandex 1%
# 4  Composition\nCotton 72%, Polyester 20%, Modal ...
#
#                                          description  ...        lining  \
# 0  5-pocket jeans in washed stretch denim. Heavil...  ...  Not Informed
# 1  5-pocket jeans in washed stretch denim. Heavil...  ...  Not Informed
# 2  5-pocket jeans in washed stretch denim. Heavil...  ...  Not Informed
# 3  5-pocket jeans in washed stretch denim. Heavil...  ...  Not Informed
# 4  5-pocket jeans in washed stretch denim. Heavil...  ...  Not Informed
#
#   cotton polyester spandex modal elastomultiester is_promo final_price  \
# 0     91         7       2   NaN              NaN        0       39.99
# 1     93         6       1   NaN              NaN        0       39.99
# 2     93         6       1   NaN              NaN        0       39.99
# 3     99       NaN       1   NaN              NaN        0       39.99
# 4     72        20       1     7              NaN        0       39.99
#
#    original_price                 date
# 0           39.99  2022-05-31 20:25:14
# 1           39.99  2022-05-31 20:25:14
# 2           39.99  2022-05-31 20:25:14
# 3           39.99  2022-05-31 20:25:14
# 4           39.99  2022-05-31 20:25:14
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Converting Data Types

# %%
# converting dtypes to numeric
df_final.dtypes
# Out:
# sku                  object
# product_id           object
# color_id             object
# color                object
# headline             object
# link                 object
# price                object
# fit                  object
# composition          object
# description          object
# text                 object
# comp                 object
# lining               object
# cotton               object
# polyester            object
# spandex              object
# modal                object
# elastomultiester     object
# is_promo              int64
# final_price         float64
# original_price      float64
# date                 object
# dtype: object

# %%
# fill NAs
df_final.isna().sum()
# Out:
# sku                   0
# product_id            0
# color_id              0
# color                 0
# headline              0
# link                  0
# price                 0
# fit                   0
# composition           0
# description           0
# text                  0
# comp                  0
# lining                0
# cotton                0
# polyester           152
# spandex              35
# modal               173
# elastomultiester    169
# is_promo              0
# final_price           0
# original_price        0
# date                  0
# dtype: int64

# %%
# fill NAs as 0 on rows that do not have the above material
df_final.fillna(0, inplace = True)

# %%
# selects all numerical columns
cols_to_num = list(df_final.columns)
str_cols = ['sku','product_id','color_id', 'color', 'fit', 'price', 'final_price', 'original_price', 'headline', 'description', 'composition', 'comp', 'lining', 'text', 'link', 'date']
for col in str_cols:
    cols_to_num.remove(col)

cols_to_num
print(cols_to_num)

for col in cols_to_num:
    try:
        # convert to float then to int (to avoid NA to int error)
        df_final[col] = df_final[col].astype(int)
    except:
        df_final[col] = df_final[col].astype('Int64')
    finally:
        pass

# converting date to datetime
df_final['date'] = pd.to_datetime( df_final['date'], errors = 'coerce')
# Out:
# ['cotton', 'polyester', 'spandex', 'modal', 'elastomultiester', 'is_promo']

# %%
df_final.dtypes
# Out:
# sku                         object
# product_id                  object
# color_id                    object
# color                       object
# headline                    object
# link                        object
# price                       object
# fit                         object
# composition                 object
# description                 object
# text                        object
# comp                        object
# lining                      object
# cotton                       int64
# polyester                    int64
# spandex                      int64
# modal                        int64
# elastomultiester             int64
# is_promo                     int64
# final_price                float64
# original_price             float64
# date                datetime64[ns]
# dtype: object

# %% [markdown]
# # Data Saving

# %% [markdown]
# ## Saving Locally

# %%
# dropping unnecessary columns 

df_final.drop(['price', 'composition', 'comp'], axis = 1, inplace = True)

# %%
# Saving Locally
now = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# saving df as a local backup
# relative path (can't be used on bash script)
# df_final.to_csv('../backups/df_backup-{}.csv'.format(now), index = False)

# absolute path
df_final.to_csv('/home/ubuntu/project/Web-Scraping-Jeans/backups/df_backup-{}.csv'.format(now), index = False)

print('saved: df_backup-{}.csv'.format(now))
# Out:
# saved: df_backup-2022-04-19 10:56:51.csv

# %%
df_final.dtypes
# Out:
# sku                         object
# product_id                  object
# color_id                    object
# color                       object
# headline                    object
# link                        object
# price                       object
# fit                         object
# composition                 object
# description                 object
# text                        object
# comp                        object
# lining                      object
# cotton                       int64
# polyester                    int64
# spandex                      int64
# modal                        int64
# elastomultiester             int64
# is_promo                     int64
# final_price                float64
# original_price             float64
# date                datetime64[ns]
# dtype: object

# %% [markdown]
# ## Inserting data to MySQL on AWS

# %%
# reading credentials

# relative path (can't be used on bash script)
# secrets_json = open('./secrets/secrets.json')

# absolute path
secrets_json = open('/home/ubuntu/project/Web-Scraping-Jeans/src/secrets/secrets.json')


secrets = json.load(secrets_json)

dialect =   secrets["dialect"]
driver =    secrets["driver"]
host =      secrets["host"]
username =  secrets["username"]
password =  secrets["password"]
port =      secrets["port"]
database =  secrets["database"]

url = "{}+{}://{}:{}@{}:{}/{}".format(dialect, driver, username, password, host, port, database)
# engine = create_engine(url = url, echo = True) #, pool_pre_ping = True

# %%
# instantianting engine

# creating sqlalchemy engine for connection
engine = create_engine(url, echo=True)

# creating a Session class
Session = sessionmaker(bind=engine)

# creating a session
session = Session()

# %%
# testing case a new column is added

try:
    # adding data
    df_final.to_sql('hm_showroom', con = engine, if_exists='append', index = False)

    # committing changes
    session.commit()
except:
    try:
        # in case scraped data returns with a new column, it will be added to a new table
        table_name = "hm_showroom_backup-{}".format(datetime.now().strftime("%Y-%m-%d"))
        df_final.to_sql( table_name, con = engine, if_exists='append', index = False)

        session.commit()
    except:  
        # if even this fails, undo everything      
        session.rollback()

finally:
    session.close()

# USE THIS SCRIPT TO PREVENT FAILS
# Out:
# 2022-04-19 11:14:47,131 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2022-04-19 11:14:47,133 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-04-19 11:14:47,176 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2022-04-19 11:14:47,178 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-04-19 11:14:47,201 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2022-04-19 11:14:47,202 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-04-19 11:14:47,267 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2022-04-19 11:14:47,269 INFO sqlalchemy.engine.Engine [generated in 0.00163s] {'table_schema': 'humberto_personal_projects', 'table_name': 'hm_showroom'}
# 2022-04-19 11:14:47,316 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-04-19 11:14:47,351 INFO sqlalchemy.engine.Engine INSERT INTO hm_showroom (sku, product_id, color_id, color, headline, link, fit, description, text, lining, cotton, polyester, spandex, modal, elastomultiester, is_promo, final_price, original_price, date) VALUES (%(sku)s, %(product_id)s, %(color_id)s, %(color)s, %(headline)s, %(link)s, %(fit)s, %(description)s, %(text)s, %(lining)s, %(cotton)s, %(polyester)s, %(spandex)s, %(modal)s, %(elastomultiester)s, %(is_promo)s, %(final_price)s, %(original_price)s, %(date)s)
# 2022-04-19 11:14:47,353 INFO sqlalchemy.engine.Engine [generated in 0.02298s] ({'sku': '0427159001', 'product_id': '0427159', 'color_id': '001', 'color': 'Black denim', 'headline': 'Trashed Skinny Jeans', 'link': 'https://www2.hm.com/en_us/productpage.0427159001.html', 'fit': 'Skinny', 'description': '5-pocket jeans in washed stretch denim. Heavily distressed details, regular waist, and button fly. Skinny legs.', 'text': 'FitSkinny fit /CompositionCotton 91%, Polyester 7%, Spandex 2% /Art. No.0427159001', 'lining': 'Not Informed', 'cotton': 91, 'polyester': 7, 'spandex': 2, 'modal': 0, 'elastomultiester': 0, 'is_promo': 0, 'final_price': 39.99, 'original_price': 39.99, 'date': datetime.datetime(2022, 4, 19, 10, 50, 36)}, {'sku': '0427159002', 'product_id': '0427159', 'color_id': '002', 'color': 'Blue washed out', 'headline': 'Trashed Skinny Jeans', 'link': 'https://www2.hm.com/en_us/productpage.0427159002.html', 'fit': 'Skinny', 'description': '5-pocket jeans in washed stretch denim. Heavily distressed details, regular waist, and button fly. Skinny legs.', 'text': 'FitSkinny fit /CompositionCotton 93%, Polyester 6%, Spandex 1% /Art. No.0427159002', 'lining': 'Not Informed', 'cotton': 93, 'polyester': 6, 'spandex': 1, 'modal': 0, 'elastomultiester': 0, 'is_promo': 0, 'final_price': 39.99, 'original_price': 39.99, 'date': datetime.datetime(2022, 4, 19, 10, 50, 36)}, {'sku': '0427159003', 'product_id': '0427159', 'color_id': '003', 'color': 'Denim blue', 'headline': 'Trashed Skinny Jeans', 'link': 'https://www2.hm.com/en_us/productpage.0427159003.html', 'fit': 'Skinny', 'description': '5-pocket jeans in washed stretch denim. Heavily distressed details, regular waist, and button fly. Skinny legs.', 'text': 'FitSkinny fit /CompositionCotton 93%, Polyester 6%, Spandex 1% /Art. No.0427159003', 'lining': 'Not Informed', 'cotton': 93, 'polyester': 6, 'spandex': 1, 'modal': 0, 'elastomultiester': 0, 'is_promo': 0, 'final_price': 39.99, 'original_price': 39.99, 'date': datetime.datetime(2022, 4, 19, 10, 50, 36)}, {'sku': '0427159004', 'product_id': '0427159', 'color_id': '004', 'color': 'Light denim blue', 'headline': 'Trashed Skinny Jeans', 'link': 'https://www2.hm.com/en_us/productpage.0427159004.html', 'fit': 'Skinny', 'description': '5-pocket jeans in washed stretch denim. Heavily distressed details, regular waist, and button fly. Skinny legs.', 'text': 'FitSkinny fit /CompositionCotton 99%, Spandex 1% /Art. No.0427159004', 'lining': 'Not Informed', 'cotton': 99, 'polyester': 0, 'spandex': 1, 'modal': 0, 'elastomultiester': 0, 'is_promo': 0, 'final_price': 39.99, 'original_price': 39.99, 'date': datetime.datetime(2022, 4, 19, 10, 50, 36)}, {'sku': '0427159005', 'product_id': '0427159', 'color_id': '005', 'color': 'Dark denim blue', 'headline': 'Trashed Skinny Jeans', 'link': 'https://www2.hm.com/en_us/productpage.0427159005.html', 'fit': 'Skinny', 'description': '5-pocket jeans in washed stretch denim. Heavily distressed details, regular waist, and button fly. Skinny legs.', 'text': 'FitSkinny fit /CompositionCotton 72%, Polyester 20%, Modal 7%, Spandex 1% /Art. No.0427159005', 'lining': 'Not Informed', 'cotton': 72, 'polyester': 20, 'spandex': 1, 'modal': 7, 'elastomultiester': 0, 'is_promo': 0, 'final_price': 39.99, 'original_price': 39.99, 'date': datetime.datetime(2022, 4, 19, 10, 50, 36)}, {'sku': '0427159006', 'product_id': '0427159', 'color_id': '006', 'color': 'Light denim blue', 'headline': 'Trashed Skinny Jeans', 'link': 'https://www2.hm.com/en_us/productpage.0427159006.html', 'fit': 'Skinny', 'description': '5-pocket jeans in washed stretch denim. Heavily distressed details, regular waist, and button fly. Skinny legs.', 'text': 'SizeThe model is 184cm/6\'0" and wears a size 31/32 /FitSkinny fit /CompositionCotton 93%, Polyester 6%, Spandex 1% /Art. No.0427159006', 'lining': 'Not Informed', 'cotton': 93, 'polyester': 6, 'spandex': 1, 'modal': 0, 'elastomultiester': 0, 'is_promo': 0, 'final_price': 39.99, 'original_price': 3 ...
# 2022-04-19 11:14:47,499 INFO sqlalchemy.engine.Engine COMMIT

# %%
session.close()

# %%
print('Job done')

# %% [markdown]
# **Brainstorm of solutions**
# - increase sleep time
# - change EC.wait from located to visible
# - add implicit wait
# - open and close a new driver
# - add explicit wait after loading page
# - clear driver cache at the end of each execution

# %% [markdown]
# Solution Attempts
#
# - remove sleep and use visibility_of_element_located
#     - 5/170
# - use visibility_of_element_located
#     - 26/170
# - add a implicitly wait and use time sleep  10 (v6)
#     - 51/176
# - use driver.close every loop doesn't work
#     - driver.close and driver.quit both kill the process if using a single page
# - use implicity wait, visibility_of_element_located, explicit sleep and open and close a driver for each page (safest way)
#     - worked well so far
#
# Conclusions
#
# Due to some error the mozila driver wasn't working properlly if used continuously. This way I am opening and closing a new driver for each page scraped,
# also I added a 20s implicit wait to make sure the page was properly loaded
